# %% [markdown]
# # Making FinCast embeddings  with Colab

# %% [markdown]
# ## Setup

# %% [markdown]
# You will need to upload fincast-embedder.py, fincast-star-embedder.py, fincast-setup.sh and processed.zip to your google drive.

# %%
from google.colab import drive
import shutil
import os

# Mount Drive
drive.mount('/content/drive')

# Copy and Unzip files to local VM (Much faster than reading from Drive)
# Adjust 'My Drive/path_to_your_files' to where you uploaded them
# !cp "/content/drive/My Drive/processed.zip" .
# !cp "/content/drive/My Drive/fincast-embeds.py" .
# !cp "/content/drive/My Drive/fincast-star-embeds.py" .
# !cp "/content/drive/My Drive/fincast_setup.sh" .

# !mkdir -p data/processed/

# !mkdir -p data/embeddings/

# !unzip -q data/processed/ processed.zip

# Install Dependencies
# !pip install pandas pyarrow tqdm einx colt5_attention utilsforecast
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cp: cannot stat '/content/drive/My Drive/fincast_setup.sh': No such file or directory
# replace __MACOSX/._processed? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# mkdir: cannot create directory ‘embeddings/’: File exists
# ...

# %% [markdown]
# Download the model weights and code.

# %%
# !mkdir weights/
# !chmod +x ./fincast-setup.sh
# !./fincast-setup.sh
# Out:
# mkdir: cannot create directory ‘weights/’: File exists
# fatal: destination path 'FinCast-fts' already exists and is not an empty directory.
# mv: cannot move 'FinCast-fts/' to 'fincast/FinCast-fts': Directory not empty
# sed: can't read s/name="my_project"/name="fincast"/g: No such file or directory
# error: No `pyproject.toml` found in current directory or any parent directory
# --2025-12-01 03:08:38--  https://huggingface.co/Vincent05R/FinCast/resolve/main/v1.pth
# Resolving huggingface.co (huggingface.co)... 18.238.109.102, 18.238.109.92, 18.238.109.121, ...
# Connecting to huggingface.co (huggingface.co)|18.238.109.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# Ignore the error. It is necessary when running the code locally.

# %% [markdown]
# Move the fincast code to the current directory.

# %%
# !mv fincast/src/*

# %% [markdown]
# Run the embedder for ptb-xl, esc-50 and SP-500.

# %%
# !python fincast-embeds.py
# Out:
# Loaded PyTorch FinCast, python version 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0].
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# Initializing model...
# Using NVIDIA GPU: Tesla T4
# Loading weights...
#
# Processing ptb-xl-train...
# Total rows: 19601. Processing in chunks of 2500...
# Successfully saved to embeddings/FinCast-ptb-xl-train.parquet

# %% [markdown]
# Run the embedder for StarEmbed.

# %%
# !python fincast-star-embeds.py
